# %% [markdown]
# # Análisis de Ingresos Públicos Brasil

# %%
# cargo librerías
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import googletrans
import os
from googletrans import Translator
from src import soporte_limpieza as sl

# %% [markdown]
# # Fase 1. Exploración de archivos individuales.

# %%
sl.traducir_columnas_y_guardar("datos-2021.csv", "BD/datos-2021-es.csv") # traduzco el nombre de las columnas
# Out:
# Error al traducir o guardar el archivo datos-2021.csv: [Errno 2] No such file or directory: 'datos-2021.csv'

# %%
ruta_2013 = "BD/datos-2013-es.csv"
ruta_2014 = "BD/datos-2014-es.csv"
ruta_2015 = "BD/datos-2015-es.csv"
ruta_2016 = "BD/datos-2016-es.csv"
ruta_2017 = "BD/datos-2017-es.csv"
ruta_2018 = "BD/datos-2018-es.csv"
ruta_2019 = "BD/datos-2019-es.csv"
ruta_2020 = "BD/datos-2020-es.csv"
ruta_2021 = "BD/datos-2021-es.csv"

pd.set_option('display.max_columns', None)

# Leer el archivo
df_2013 = pd.read_csv(ruta_2013, sep=";")
df_2014 = pd.read_csv(ruta_2013, sep=";")
df_2015 = pd.read_csv(ruta_2013, sep=";")
df_2016 = pd.read_csv(ruta_2013, sep=";")
df_2017 = pd.read_csv(ruta_2013, sep=";")
df_2018 = pd.read_csv(ruta_2013, sep=";")
df_2019 = pd.read_csv(ruta_2013, sep=";")
df_2020 = pd.read_csv(ruta_2013, sep=";")
df_2021 = pd.read_csv(ruta_2013, sep=";")

# %%
# recordemos los otros dos conjuntos de datos
print("#### Dataframe2013 ####")
print("-------------------------------------------------------------------")
display(df_2013.sample(2))
df_2013.info()
df_2013.isnull().sum()
df_2013.describe()
df_2013.nunique()
df_2013.duplicated().sum




print("#### Dataframe2014 ####")
print("-------------------------------------------------------------------")
display(df_2014.head(2))

display(df_2014.sample(2))
df_2014.info()
df_2014.isnull().sum()
df_2014.describe()
df_2014.nunique()
df_2014.duplicated().sum()

print("#### DataFrame2015 ####")
print("-------------------------------------------------------------------")
display(df_2015.head(2))
display(df_2015.sample(2))
df_2015.info()
df_2015.isnull().sum()
df_2015.describe()
df_2015.nunique()
df_2015.duplicated().sum()

print("#### Dataframe2016 ####")
print("-------------------------------------------------------------------")
display(df_2016.head(2))
display(df_2016.sample(2))
df_2016.info()
df_2016.isnull().sum()
df_2016.describe()
df_2016.nunique()
df_2016.duplicated().sum()

print("#### Dataframe2017 ####")
print("-------------------------------------------------------------------")
display(df_2017.head(2))
display(df_2017.sample(2))
df_2017.info()
df_2017.isnull().sum()
df_2017.describe()
df_2017.nunique()
df_2017.duplicated().sum()

print("#### DataFrame2018 ####")
print("-------------------------------------------------------------------")
display(df_2018.head(2))
display(df_2018.sample(2))
df_2018.info()
df_2018.isnull().sum()
df_2018.describe()
df_2018.nunique()
df_2018.duplicated().sum()
print("#### Dataframe2019 ####")
print("-------------------------------------------------------------------")
display(df_2019.head(2))
display(df_2019.sample(2))
df_2019.info()
df_2019.isnull().sum()
df_2019.describe()
df_2019.nunique()
df_2019.duplicated().sum()

print("#### Dataframe2020 ####")
print("-------------------------------------------------------------------")
display(df_2020.head(2))
display(df_2020.sample(2))
df_2020.info()
df_2020.isnull().sum()
df_2020.describe()
df_2020.nunique()
df_2020.duplicated().sum()

print("#### DataFrame2021 ####")
print("-------------------------------------------------------------------")
display(df_2021.head(2))
display(df_2021.sample(2))
df_2021.info()
df_2021.isnull().sum()
df_2021.describe()
df_2021.nunique()
df_2021.duplicated().sum()
# Out:
# #### Dataframe2013 ####
# -------------------------------------------------------------------
#       Código de órganos más alto         Nombre Superior  Código corporal  \
# 1603                       26000  Ministério da Educação            26402
# 429                        52000    Ministério da Defesa            52911
#
#                   Órgano de nombre  Código de la unidad de gestión  \
# 1603  Instituto Federal de Alagoas                          158147
# 429              Fundo Aeronáutico                          121002
#
#                  Nombre de gestión de la unidad Categoría económica  \
# 1603   INST.FED.DE EDUC.,CIENC.E TEC.DE ALAGOAS  Receitas Correntes
# 429   SECRETARIA DE ECON. E FIN.DA AER.- F.AER.  Receitas Correntes
#
#              Ingresos de origen                         Especies de ingresos  \
# 1603  Outras Receitas Correntes  Indenizações, restituições e ressarcimentos
# 429         Receita de Serviços                          Receita de Serviços
#
#                                             Detalle  \
# 1603   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES
# 429   ADICIONAL S/ TARIFA USO COM E AUX NAVEG AEREA
#
#      Valor esperado actualizado Valor lanzado       Valor Porcentaje  \
# 1603                   58402,00          0,00    56037,83      96,00
# 429                        0,00          0,00  2165924,53       0,00
#
#      Fecha de lanzamiento  Ejercicio anual
# 1603           31/12/2013             2013
# 429            31/12/2013             2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      4498 non-null   int64
#  1   Nombre Superior                 4498 non-null   object
#  2   Código corporal                 4498 non-null   int64
#  3   Órgano de nombre                4498 non-null   object
#  4   Código de la unidad de gestión  4498 non-null   int64
#  5   Nombre de gestión de la unidad  4498 non-null   object
#  6   Categoría económica             4498 non-null   object
#  7   Ingresos de origen              4498 non-null   object
#  8   Especies de ingresos            4498 non-null   object
#  9   Detalle                         4498 non-null   object
#  10  Valor esperado actualizado      4498 non-null   object
#  11  Valor lanzado                   4498 non-null   object
#  12  Valor                           4498 non-null   object
#  13  Porcentaje                      4498 non-null   object
#  14  Fecha de lanzamiento            4498 non-null   object
#  15  Ejercicio anual                 4498 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 562.4+ KB
# #### Dataframe2014 ####
# -------------------------------------------------------------------
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          Detalle Valor esperado actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                       0,00
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                       0,00
#
#   Valor lanzado        Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 0          0,00      1297,13       0,00           31/12/2013             2013
# 1          0,00  26666621,42       0,00           31/12/2013             2013
#       Código de órganos más alto                         Nombre Superior  \
# 4047                       53000  Ministério do Desenvolvimento Regional
# 1168                       25000                  Ministério da Economia
#
#       Código corporal                                   Órgano de nombre  \
# 4047            22204     Departamento Nacional de Obras Contra as Secas
# 1168            25000  Ministério da Economia - Unidades com vínculo ...
#
#       Código de la unidad de gestión  \
# 4047                          113802
# 1168                          170010
#
#                      Nombre de gestión de la unidad  Categoría económica  \
# 4047  DEPARTAMENTO NAC. DE OBRAS CONTRA AS SECAS/UO  Receitas de Capital
# 1168    SECRETARIA DA RECEITA FEDERAL DO BRASIL-RFB   Receitas Correntes
#
#              Ingresos de origen  \
# 4047          Alienação de Bens
# 1168  Outras Receitas Correntes
#
#                                Especies de ingresos  \
# 4047                       Alienação de bens móveis
# 1168  Multas administrativas, contratuais e judicia
#
#                                             Detalle  \
# 4047                ALIENACAO DE OUTROS BENS MOVEIS
# 1168  MULTAS/J.MORA CONTR.PREV.EM REG. PARCEL. DEB.
#
#      Valor esperado actualizado    Valor lanzado Valor Porcentaje  \
# 4047                   14008,00             0,00  0,00       0,00
# 1168                       0,00  100402203489,75  0,00       0,00
#
#      Fecha de lanzamiento  Ejercicio anual
# 4047           31/12/2013             2013
# 1168           31/12/2013             2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      4498 non-null   int64
#  1   Nombre Superior                 4498 non-null   object
#  2   Código corporal                 4498 non-null   int64
#  3   Órgano de nombre                4498 non-null   object
#  4   Código de la unidad de gestión  4498 non-null   int64
#  5   Nombre de gestión de la unidad  4498 non-null   object
#  6   Categoría económica             4498 non-null   object
#  7   Ingresos de origen              4498 non-null   object
#  8   Especies de ingresos            4498 non-null   object
#  9   Detalle                         4498 non-null   object
#  10  Valor esperado actualizado      4498 non-null   object
#  11  Valor lanzado                   4498 non-null   object
#  12  Valor                           4498 non-null   object
#  13  Porcentaje                      4498 non-null   object
#  14  Fecha de lanzamiento            4498 non-null   object
#  15  Ejercicio anual                 4498 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 562.4+ KB
# #### DataFrame2015 ####
# -------------------------------------------------------------------
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          Detalle Valor esperado actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                       0,00
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                       0,00
#
#   Valor lanzado        Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 0          0,00      1297,13       0,00           31/12/2013             2013
# 1          0,00  26666621,42       0,00           31/12/2013             2013
#       Código de órganos más alto         Nombre Superior  Código corporal  \
# 2871                       26000  Ministério da Educação            26412
# 650                        25000  Ministério da Economia            25000
#
#                                        Órgano de nombre  \
# 2871           Instituto Federal do Sul de Minas Gerais
# 650   Ministério da Economia - Unidades com vínculo ...
#
#       Código de la unidad de gestión  \
# 2871                          158137
# 650                           170013
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 2871  INST.FED.DE EDUC.,CIENC.E TEC.DO SUL DE MG  Receitas Correntes
# 650      SETORIAL ORCAMENTARIA E FINANCEIRA / ME  Receitas Correntes
#
#        Ingresos de origen                           Especies de ingresos  \
# 2871  Receita Patrimonial  Exploração do patrimônio imobiliário do Estad
# 650         Contribuições                       Contribuições econômicas
#
#                               Detalle Valor esperado actualizado  \
# 2871                         ALUGUEIS                  100000,00
# 650   OUTRAS CONTRIBUICOES ECONOMICAS                   11557,00
#
#      Valor lanzado     Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 2871          0,00  38143,05      38,00           31/12/2013             2013
# 650           0,00      0,00       0,00           31/12/2013             2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      4498 non-null   int64
#  1   Nombre Superior                 4498 non-null   object
#  2   Código corporal                 4498 non-null   int64
#  3   Órgano de nombre                4498 non-null   object
#  4   Código de la unidad de gestión  4498 non-null   int64
#  5   Nombre de gestión de la unidad  4498 non-null   object
#  6   Categoría económica             4498 non-null   object
#  7   Ingresos de origen              4498 non-null   object
#  8   Especies de ingresos            4498 non-null   object
#  9   Detalle                         4498 non-null   object
#  10  Valor esperado actualizado      4498 non-null   object
#  11  Valor lanzado                   4498 non-null   object
#  12  Valor                           4498 non-null   object
#  13  Porcentaje                      4498 non-null   object
#  14  Fecha de lanzamiento            4498 non-null   object
#  15  Ejercicio anual                 4498 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 562.4+ KB
# #### Dataframe2016 ####
# -------------------------------------------------------------------
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          Detalle Valor esperado actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                       0,00
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                       0,00
#
#   Valor lanzado        Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 0          0,00      1297,13       0,00           31/12/2013             2013
# 1          0,00  26666621,42       0,00           31/12/2013             2013
#       Código de órganos más alto  \
# 77                         22000
# 2729                       26000
#
#                                     Nombre Superior  Código corporal  \
# 77    Ministério da Agricultura, Pecuária e Abastec            22201
# 2729                         Ministério da Educação            26285
#
#                                        Órgano de nombre  \
# 77    Instituto Nacional de Colonização e Reforma Ag...
# 2729  Fundação Universidade Federal de São João Del-Rei
#
#       Código de la unidad de gestión  \
# 77                            373001
# 2729                          154069
#
#                      Nombre de gestión de la unidad Categoría económica  \
# 77    DPTO. DE ADMINISTRACAO FINANCEIRA-DAF - INCRA  Receitas Correntes
# 2729   FUNDACAO UNIVERSIDADE FEDERAL DE S.J.DEL-REI  Receitas Correntes
#
#              Ingresos de origen  \
# 77    Outras Receitas Correntes
# 2729        Receita de Serviços
#
#                                Especies de ingresos  \
# 77    Bens, Direitos e Valores Incorporados ao Patr
# 2729                            Receita de Serviços
#
#                                     Detalle Valor esperado actualizado  \
# 77    REC.DIV.ATIVA RESSARCIMENTO AO ERARIO                       0,00
# 2729                  SERVICOS EDUCACIONAIS                  960431,00
#
#      Valor lanzado      Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 77            0,00   74903,10       0,00           31/12/2013             2013
# 2729          0,00  396595,01      41,00           31/12/2013             2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      4498 non-null   int64
#  1   Nombre Superior                 4498 non-null   object
#  2   Código corporal                 4498 non-null   int64
#  3   Órgano de nombre                4498 non-null   object
#  4   Código de la unidad de gestión  4498 non-null   int64
#  5   Nombre de gestión de la unidad  4498 non-null   object
#  6   Categoría económica             4498 non-null   object
#  7   Ingresos de origen              4498 non-null   object
#  8   Especies de ingresos            4498 non-null   object
#  9   Detalle                         4498 non-null   object
#  10  Valor esperado actualizado      4498 non-null   object
#  11  Valor lanzado                   4498 non-null   object
#  12  Valor                           4498 non-null   object
#  13  Porcentaje                      4498 non-null   object
#  14  Fecha de lanzamiento            4498 non-null   object
#  15  Ejercicio anual                 4498 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 562.4+ KB
# #### Dataframe2017 ####
# -------------------------------------------------------------------
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          Detalle Valor esperado actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                       0,00
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                       0,00
#
#   Valor lanzado        Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 0          0,00      1297,13       0,00           31/12/2013             2013
# 1          0,00  26666621,42       0,00           31/12/2013             2013
#       Código de órganos más alto         Nombre Superior  Código corporal  \
# 3668                       36000     Ministério da Saúde            36201
# 3083                       26000  Ministério da Educação            26428
#
#                    Órgano de nombre  Código de la unidad de gestión  \
# 3668          Fundação Oswaldo Cruz                          254420
# 3083  Instituto Federal de Brasília                          158143
#
#      Nombre de gestión de la unidad Categoría económica    Ingresos de origen  \
# 3668          FUNDACAO OSWALDO CRUZ  Receitas Correntes   Receita de Serviços
# 3083   IFB - REITORIA - BRASILIA-DF  Receitas Correntes  Receita Agropecuária
#
#              Especies de ingresos  \
# 3668          Receita de Serviços
# 3083  Receita da produção vegetal
#
#                                             Detalle  \
# 3668  SERVICO DE INFORMACOES CIENTIFICAS E TECNOLOG
# 3083                    Receita da produção vegetal
#
#      Valor esperado actualizado Valor lanzado    Valor Porcentaje  \
# 3668                   30108,00          0,00  8500,00      28,00
# 3083                   67725,00          0,00  7163,26      11,00
#
#      Fecha de lanzamiento  Ejercicio anual
# 3668           31/12/2013             2013
# 3083           31/12/2013             2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      4498 non-null   int64
#  1   Nombre Superior                 4498 non-null   object
#  2   Código corporal                 4498 non-null   int64
#  3   Órgano de nombre                4498 non-null   object
#  4   Código de la unidad de gestión  4498 non-null   int64
#  5   Nombre de gestión de la unidad  4498 non-null   object
#  6   Categoría económica             4498 non-null   object
#  7   Ingresos de origen              4498 non-null   object
#  8   Especies de ingresos            4498 non-null   object
#  9   Detalle                         4498 non-null   object
#  10  Valor esperado actualizado      4498 non-null   object
#  11  Valor lanzado                   4498 non-null   object
#  12  Valor                           4498 non-null   object
#  13  Porcentaje                      4498 non-null   object
#  14  Fecha de lanzamiento            4498 non-null   object
#  15  Ejercicio anual                 4498 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 562.4+ KB
# #### DataFrame2018 ####
# -------------------------------------------------------------------
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          Detalle Valor esperado actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                       0,00
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                       0,00
#
#   Valor lanzado        Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 0          0,00      1297,13       0,00           31/12/2013             2013
# 1          0,00  26666621,42       0,00           31/12/2013             2013
#       Código de órganos más alto         Nombre Superior  Código corporal  \
# 2841                       26000  Ministério da Educação            26419
# 2205                       26000  Ministério da Educação            26280
#
#                                  Órgano de nombre  \
# 2841       Instituto Federal do Rio Grande do Sul
# 2205  Fundação Universidade Federal de São Carlos
#
#       Código de la unidad de gestión  \
# 2841                          158141
# 2205                          154049
#
#                    Nombre de gestión de la unidad  \
# 2841          INST.FED.DE EDUC.,CIENC.E TEC.DO RS
# 2205  FUNDACAO UNIVERSIDADE FEDERAL DE SAO CARLOS
#
#                            Categoría económica         Ingresos de origen  \
# 2841                        Receitas Correntes  Outras Receitas Correntes
# 2205  Receitas Correntes - intra-orçamentárias        Receita de Serviços
#
#                                Especies de ingresos                 Detalle  \
# 2841  Multas administrativas, contratuais e judicia           OUTRAS MULTAS
# 2205                            Receita de Serviços  SERVICOS DE TECNOLOGIA
#
#      Valor esperado actualizado Valor lanzado       Valor Porcentaje  \
# 2841                    5846,00          0,00    11845,89     203,00
# 2205                       0,00          0,00  2112251,54       0,00
#
#      Fecha de lanzamiento  Ejercicio anual
# 2841           31/12/2013             2013
# 2205           31/12/2013             2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      4498 non-null   int64
#  1   Nombre Superior                 4498 non-null   object
#  2   Código corporal                 4498 non-null   int64
#  3   Órgano de nombre                4498 non-null   object
#  4   Código de la unidad de gestión  4498 non-null   int64
#  5   Nombre de gestión de la unidad  4498 non-null   object
#  6   Categoría económica             4498 non-null   object
#  7   Ingresos de origen              4498 non-null   object
#  8   Especies de ingresos            4498 non-null   object
#  9   Detalle                         4498 non-null   object
#  10  Valor esperado actualizado      4498 non-null   object
#  11  Valor lanzado                   4498 non-null   object
#  12  Valor                           4498 non-null   object
#  13  Porcentaje                      4498 non-null   object
#  14  Fecha de lanzamiento            4498 non-null   object
#  15  Ejercicio anual                 4498 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 562.4+ KB
# #### Dataframe2019 ####
# -------------------------------------------------------------------
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          Detalle Valor esperado actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                       0,00
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                       0,00
#
#   Valor lanzado        Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 0          0,00      1297,13       0,00           31/12/2013             2013
# 1          0,00  26666621,42       0,00           31/12/2013             2013
#       Código de órganos más alto         Nombre Superior  Código corporal  \
# 2105                       26000  Ministério da Educação            26437
# 3682                       36000     Ministério da Saúde            36211
#
#                   Órgano de nombre  Código de la unidad de gestión  \
# 2105  Instituto Federal de Roraima                          158152
# 3682    Fundação Nacional de Saúde                          255000
#
#                 Nombre de gestión de la unidad Categoría económica  \
# 2105  INST.FED.DE EDUC.,CIENC.E TEC.DE RORAIMA  Receitas Correntes
# 3682           FUNDACAO NACIONAL DE SAUDE - DF  Receitas Correntes
#
#        Ingresos de origen                           Especies de ingresos  \
# 2105  Receita de Serviços                            Receita de Serviços
# 3682  Receita Patrimonial  Exploração do patrimônio imobiliário do Estad
#
#                                            Detalle Valor esperado actualizado  \
# 2105     TAR.INSCR.CONCURSOS E PROCESSOS SELETIVOS                  206528,00
# 3682  TAXA OCUPACAO IMOVEIS FUN. PROP. NAC. RESID.                       0,00
#
#      Valor lanzado     Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 2105          0,00  68440,00      33,00           31/12/2013             2013
# 3682          0,00  47373,12       0,00           31/12/2013             2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      4498 non-null   int64
#  1   Nombre Superior                 4498 non-null   object
#  2   Código corporal                 4498 non-null   int64
#  3   Órgano de nombre                4498 non-null   object
#  4   Código de la unidad de gestión  4498 non-null   int64
#  5   Nombre de gestión de la unidad  4498 non-null   object
#  6   Categoría económica             4498 non-null   object
#  7   Ingresos de origen              4498 non-null   object
#  8   Especies de ingresos            4498 non-null   object
#  9   Detalle                         4498 non-null   object
#  10  Valor esperado actualizado      4498 non-null   object
#  11  Valor lanzado                   4498 non-null   object
#  12  Valor                           4498 non-null   object
#  13  Porcentaje                      4498 non-null   object
#  14  Fecha de lanzamiento            4498 non-null   object
#  15  Ejercicio anual                 4498 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 562.4+ KB
# #### Dataframe2020 ####
# -------------------------------------------------------------------
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          Detalle Valor esperado actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                       0,00
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                       0,00
#
#   Valor lanzado        Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 0          0,00      1297,13       0,00           31/12/2013             2013
# 1          0,00  26666621,42       0,00           31/12/2013             2013
#       Código de órganos más alto         Nombre Superior  Código corporal  \
# 1998                       26000  Ministério da Educação            26281
# 2861                       26000  Ministério da Educação            26246
#
#                               Órgano de nombre  \
# 1998  Fundação Universidade Federal de Sergipe
# 2861    Universidade Federal de Santa Catarina
#
#       Código de la unidad de gestión  \
# 1998                          154050
# 2861                          153163
#
#                 Nombre de gestión de la unidad Categoría económica  \
# 1998  FUNDACAO UNIVERSIDADE FEDERAL DE SERGIPE  Receitas Correntes
# 2861    UNIVERSIDADE FEDERAL DE SANTA CATARINA  Receitas Correntes
#
#        Ingresos de origen                           Especies de ingresos  \
# 1998  Receita de Serviços                            Receita de Serviços
# 2861  Receita Patrimonial  Exploração do patrimônio imobiliário do Estad
#
#                               Detalle Valor esperado actualizado  \
# 1998  SERVICOS DE ESTUDOS E PESQUISAS                  326792,00
# 2861                         ALUGUEIS                 1753223,00
#
#      Valor lanzado       Valor Porcentaje Fecha de lanzamiento  \
# 1998          0,00   234406,10      72,00           31/12/2013
# 2861          0,00  1398936,96      80,00           31/12/2013
#
#       Ejercicio anual
# 1998             2013
# 2861             2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      4498 non-null   int64
#  1   Nombre Superior                 4498 non-null   object
#  2   Código corporal                 4498 non-null   int64
#  3   Órgano de nombre                4498 non-null   object
#  4   Código de la unidad de gestión  4498 non-null   int64
#  5   Nombre de gestión de la unidad  4498 non-null   object
#  6   Categoría económica             4498 non-null   object
#  7   Ingresos de origen              4498 non-null   object
#  8   Especies de ingresos            4498 non-null   object
#  9   Detalle                         4498 non-null   object
#  10  Valor esperado actualizado      4498 non-null   object
#  11  Valor lanzado                   4498 non-null   object
#  12  Valor                           4498 non-null   object
#  13  Porcentaje                      4498 non-null   object
#  14  Fecha de lanzamiento            4498 non-null   object
#  15  Ejercicio anual                 4498 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 562.4+ KB
# #### DataFrame2021 ####
# -------------------------------------------------------------------
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          Detalle Valor esperado actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                       0,00
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                       0,00
#
#   Valor lanzado        Valor Porcentaje Fecha de lanzamiento  Ejercicio anual
# 0          0,00      1297,13       0,00           31/12/2013             2013
# 1          0,00  26666621,42       0,00           31/12/2013             2013
#       Código de órganos más alto                Nombre Superior  \
# 928                        25000         Ministério da Economia
# 3816                       32000  Ministério de Minas e Energia
#
#       Código corporal                                   Órgano de nombre  \
# 928             25000  Ministério da Economia - Unidades com vínculo ...
# 3816            29208         Companhia de Pesquisa de Recursos Minerais
#
#       Código de la unidad de gestión  \
# 928                           170013
# 3816                          495001
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 928      SETORIAL ORCAMENTARIA E FINANCEIRA / ME  Receitas Correntes
# 3816  COMPANHIA DE PESQUISA DE RECURSOS MINERAIS  Receitas Correntes
#
#              Ingresos de origen  \
# 928   Outras Receitas Correntes
# 3816        Receita Patrimonial
#
#                                Especies de ingresos  \
# 928   Multas administrativas, contratuais e judicia
# 3816                Exploração de recursos naturais
#
#                                             Detalle  \
# 928   MULT.JUR MOR DIV ATIV TAXA FISC DE INSTALACAO
# 3816   PART.ESPEC.PROD.PETRO.OU GAS NAT(CONCES.2009
#
#      Valor esperado actualizado Valor lanzado     Valor Porcentaje  \
# 928                    12254,00          0,00  16901,20     138,00
# 3816              1190722151,00          0,00      0,00       0,00
#
#      Fecha de lanzamiento  Ejercicio anual
# 928            31/12/2013             2013
# 3816           31/12/2013             2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4498 entries, 0 to 4497
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      4498 non-null   int64
#  1   Nombre Superior                 4498 non-null   object
#  2   Código corporal                 4498 non-null   int64
#  3   Órgano de nombre                4498 non-null   object
#  4   Código de la unidad de gestión  4498 non-null   int64
#  5   Nombre de gestión de la unidad  4498 non-null   object
#  6   Categoría económica             4498 non-null   object
#  7   Ingresos de origen              4498 non-null   object
#  8   Especies de ingresos            4498 non-null   object
#  9   Detalle                         4498 non-null   object
#  10  Valor esperado actualizado      4498 non-null   object
#  11  Valor lanzado                   4498 non-null   object
#  12  Valor                           4498 non-null   object
#  13  Porcentaje                      4498 non-null   object
#  14  Fecha de lanzamiento            4498 non-null   object
#  15  Ejercicio anual                 4498 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 562.4+ KB
# 0

# %% [markdown]
# # Unión de dataframes

# %%
# Crear una lista con todos los DataFrames
dataframes = [df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021]

# Agregar una columna para identificar el año, si no existe ya
for year, df in zip(range(2013, 2022), dataframes):
    df['Año'] = year

# Concatenar todos los DataFrames en uno solo
df = pd.concat(dataframes, ignore_index=True)

# %%
df.sample(5)
# Out:
#        Código de órganos más alto                            Nombre Superior  \
# 9785                        25000                     Ministério da Economia
# 35076                       36000                        Ministério da Saúde
# 26017                       30000  Ministério da Justiça e Segurança Pública
# 22899                       52000                       Ministério da Defesa
# 29777                       26000                     Ministério da Educação
#
#        Código corporal                                   Órgano de nombre  \
# 9785             20603          Superintendência da Zona Franca de Manaus
# 35076            36212           Agência Nacional de Vigilância Sanitária
# 26017            30907                       Fundo Penitenciário Nacional
# 22899            52211  Caixa de Financiamento Imobiliário da Aeronáutica
# 29777            26274        Fundação Universidade Federal de Uberlândia
#
#        Código de la unidad de gestión  \
# 9785                           193028
# 35076                          253002
# 26017                          200333
# 22899                          123001
# 29777                          154043
#
#                      Nombre de gestión de la unidad  \
# 9785   SUPERINTENDENCIA DA ZONA FRANCA DE MANAUS/AM
# 35076      AGENCIA NACIONAL DE VIGILANCIA SANITARIA
# 26017                   DEPEN - DIRETORIA EXECUTIVA
# 22899   CAIXA FINANCIAMENTO IMOBILIARIO AERONAUTICA
# 29777   FUNDACAO UNIVERSIDADE FEDERAL DE UBERLANDIA
#
#                             Categoría económica  \
# 9785                         Receitas Correntes
# 35076                        Receitas Correntes
# 26017                        Receitas Correntes
# 22899                       Receitas de Capital
# 29777  Receitas Correntes - intra-orçamentárias
#
#                                 Ingresos de origen  \
# 9785   Impostos, Taxas e Contribuições de Melhoria
# 35076                    Outras Receitas Correntes
# 26017                                Contribuições
# 22899                  Amortizações de Empréstimos
# 29777                          Receita Patrimonial
#
#                                 Especies de ingresos  \
# 9785                                           Taxas
# 35076  Multas administrativas, contratuais e judicia
# 26017                          Contribuições sociais
# 22899                    Amortizações de Empréstimos
# 29777  Exploração do patrimônio imobiliário do Estad
#
#                                              Detalle  \
# 9785          TAXA DE SERVICOS ADMINISTRATIVOS - TSA
# 35076                  OUTRAS MULTAS E JUROS DE MORA
# 26017  CONTR.S/REC.CONC.PROG.DEST.PRAT.DESP-MOD.FUTE
# 22899                           AMORTIZACOES DE BENS
# 29777                                       ALUGUEIS
#
#       Valor esperado actualizado Valor lanzado         Valor Porcentaje  \
# 9785                485761023,00          0,00  484924646,35     100,00
# 35076                  162698,00          0,00      32708,47      20,00
# 26017                 6182905,00          0,00          0,00       0,00
# 22899                  844972,00          0,00     587830,55      70,00
# 29777                   63509,00          0,00      60000,00      94,00
#
#       Fecha de lanzamiento  Ejercicio anual   Año
# 9785            31/12/2013             2013  2015
# 35076           31/12/2013             2013  2020
# 26017           31/12/2013             2013  2018
# 22899           31/12/2013             2013  2018
# 29777           31/12/2013             2013  2019

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40482 entries, 0 to 40481
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código de órganos más alto      40482 non-null  int64
#  1   Nombre Superior                 40482 non-null  object
#  2   Código corporal                 40482 non-null  int64
#  3   Órgano de nombre                40482 non-null  object
#  4   Código de la unidad de gestión  40482 non-null  int64
#  5   Nombre de gestión de la unidad  40482 non-null  object
#  6   Categoría económica             40482 non-null  object
#  7   Ingresos de origen              40482 non-null  object
#  8   Especies de ingresos            40482 non-null  object
#  9   Detalle                         40482 non-null  object
#  10  Valor esperado actualizado      40482 non-null  object
#  11  Valor lanzado                   40482 non-null  object
#  12  Valor                           40482 non-null  object
#  13  Porcentaje                      40482 non-null  object
#  14  Fecha de lanzamiento            40482 non-null  object
#  15  Ejercicio anual                 40482 non-null  int64
#  16  Año                             40482 non-null  int64
# dtypes: int64(5), object(12)
# memory usage: 5.3+ MB

# %%
# Cambiar columnas numéricas (reemplaza caracteres no numéricos, como comas o %)
cols_numericas = ['Valor esperado actualizado', 'Valor lanzado', 'Valor']
for col in cols_numericas:
    df[col] = pd.to_numeric(df[col].str.replace(',', '').str.replace('%', ''), errors='coerce')

# Verificar los tipos de datos actualizados
print(df.dtypes)
# Out:
# Código de órganos más alto         int64
# Nombre Superior                   object
# Código corporal                    int64
# Órgano de nombre                  object
# Código de la unidad de gestión     int64
# Nombre de gestión de la unidad    object
# Categoría económica               object
# Ingresos de origen                object
# Especies de ingresos              object
# Detalle                           object
# Valor esperado actualizado         int64
# Valor lanzado                      int64
# Valor                              int64
# Porcentaje                        object
# Fecha de lanzamiento              object
# Ejercicio anual                    int64
# Año                                int64
# dtype: object

# %%
df['Porcentaje'] = df['Porcentaje'].str.replace('.', '').str.replace(',', '.').astype(float)

# %%
# Cambiar columnas de fecha
df['Fecha de lanzamiento'] = pd.to_datetime(df['Fecha de lanzamiento'], errors='coerce')
# Out:
# C:\Users\marta\AppData\Local\Temp\ipykernel_48624\2597158670.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Fecha de lanzamiento'] = pd.to_datetime(df['Fecha de lanzamiento'], errors='coerce')

# %%
df.sample(3)
# Out:
#        Código de órganos más alto  \
# 31539                       22000
# 4063                        53000
# 20168                       26000
#
#                                      Nombre Superior  Código corporal  \
# 31539  Ministério da Agricultura, Pecuária e Abastec            22211
# 4063          Ministério do Desenvolvimento Regional            53901
# 20168                         Ministério da Educação            26426
#
#                                      Órgano de nombre  \
# 31539             Companhia Nacional de Abastecimento
# 4063   Fundo Constitucional de Financiamento do Norte
# 20168                      Instituto Federal do Amapá
#
#        Código de la unidad de gestión  \
# 31539                          135100
# 4063                           537002
# 20168                          158150
#
#                  Nombre de gestión de la unidad  Categoría económica  \
# 31539       COMPANHIA NACIONAL DE ABASTECIMENTO  Receitas de Capital
# 4063   FUNDO CONSTITUCIONAL FINANCIAMENTO NORTE   Receitas Correntes
# 20168    INST.FED.DE EDUC.,CIENC.E TEC.DO AMAPA   Receitas Correntes
#
#                                 Ingresos de origen      Especies de ingresos  \
# 31539                            Alienação de Bens  Alienação de bens móveis
# 4063   Impostos, Taxas e Contribuições de Melhoria                  Impostos
# 20168                          Receita de Serviços       Receita de Serviços
#
#                                          Detalle  Valor esperado actualizado  \
# 31539           ALIENACAO DE TITULOS MOBILIARIOS                           0
# 4063      RETIDO NAS FONTES - OUTROS RENDIMENTOS                  5069141300
# 20168  TAR.INSCR.CONCURSOS E PROCESSOS SELETIVOS                    15072800
#
#        Valor lanzado     Valor  Porcentaje Fecha de lanzamiento  \
# 31539              0     -3520         0.0           2013-12-31
# 4063               0         0         0.0           2013-12-31
# 20168              0  23518000       156.0           2013-12-31
#
#        Ejercicio anual   Año
# 31539             2013  2020
# 4063              2013  2013
# 20168             2013  2017

# %%
df_2013.sample(4)
# Out:
#       Código de órganos más alto              Nombre Superior  \
# 1788                       26000       Ministério da Educação
# 4247                       44000  Ministério do Meio Ambiente
# 1925                       26000       Ministério da Educação
# 1638                       26000       Ministério da Educação
#
#       Código corporal                                   Órgano de nombre  \
# 1788            26409                  Instituto Federal de Minas Gerais
# 4247            44000  Ministério do Meio Ambiente - Unidades com vín...
# 1925            26248           Universidade Federal Rural de Pernambuco
# 1638            26415            Instituto Federal do Mato Grosso do Sul
#
#       Código de la unidad de gestión  \
# 1788                          158122
# 4247                          440002
# 1925                          153165
# 1638                          158132
#
#                      Nombre de gestión de la unidad Categoría económica  \
# 1788  INST.FED.DE EDUC.,CIENC.E TEC.DE MINAS GERAIS  Receitas Correntes
# 4247  SUBSECRET.PLANEJAM.ORCAM.E ADMINIST±SPOA(MMA)  Receitas Correntes
# 1925       UNIVERSIDADE FEDERAL RURAL DE PERNAMBUCO  Receitas Correntes
# 1638  INST.FED.DE EDUC.,CIENC.E TEC.DO MAT.G.DO SUL  Receitas Correntes
#
#              Ingresos de origen  \
# 1788         Receita Industrial
# 4247  Outras Receitas Correntes
# 1925  Outras Receitas Correntes
# 1638  Outras Receitas Correntes
#
#                                Especies de ingresos  \
# 1788         Receitas da indústria de transformação
# 4247  Multas administrativas, contratuais e judicia
# 1925    Indenizações, restituições e ressarcimentos
# 1638    Indenizações, restituições e ressarcimentos
#
#                                            Detalle Valor esperado actualizado  \
# 1788      RECEITA DA INDUSTRIA EDITORIAL E GRAFICA                    3902,00
# 4247                 OUTRAS MULTAS E JUROS DE MORA                       0,00
# 1925                           OUTRAS RESTITUICOES                  221272,00
# 1638  RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                       0,00
#
#      Valor lanzado       Valor Porcentaje Fecha de lanzamiento  \
# 1788          0,00        0,00       0,00           31/12/2013
# 4247          0,00   186962,68       0,00           31/12/2013
# 1925          0,00  1227151,60     555,00           31/12/2013
# 1638          0,00     2583,51       0,00           31/12/2013
#
#       Ejercicio anual   Año
# 1788             2013  2013
# 4247             2013  2013
# 1925             2013  2013
# 1638             2013  2013

# %%
print(df.columns)
# Out:
# Index(['Código de órganos más alto', 'Nombre Superior', 'Código corporal',
#        'Órgano de nombre', 'Código de la unidad de gestión',
#        'Nombre de gestión de la unidad', 'Categoría económica',
#        'Ingresos de origen', 'Especies de ingresos', 'Detalle',
#        'Valor esperado actualizado', 'Valor lanzado', 'Valor', 'Porcentaje',
#        'Fecha de lanzamiento', 'Ejercicio anual', 'Año'],
#       dtype='object')

# %%
df.drop("Ejercicio anual", axis=1, inplace=True)
df.head(2)
# Out:
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          Detalle  Valor esperado actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                           0
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                           0
#
#    Valor lanzado       Valor  Porcentaje Fecha de lanzamiento   Año
# 0              0      129713         0.0           2013-12-31  2013
# 1              0  2666662142         0.0           2013-12-31  2013

# %%
df.nunique()
# Out:
# Código de órganos más alto          25
# Nombre Superior                     25
# Código corporal                    268
# Órgano de nombre                   266
# Código de la unidad de gestión     283
# Nombre de gestión de la unidad     279
# Categoría económica                  5
# Ingresos de origen                  15
# Especies de ingresos                44
# Detalle                            704
# Valor esperado actualizado        2788
# Valor lanzado                       52
# Valor                             3738
# Porcentaje                         578
# Fecha de lanzamiento                 1
# Año                                  9
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Ver cuántos ceros hay por columna
ceros_por_columna = (df == 0).sum()
print(ceros_por_columna)
# Out:
# Código de órganos más alto            0
# Nombre Superior                       0
# Código corporal                       0
# Órgano de nombre                      0
# Código de la unidad de gestión        0
# Nombre de gestión de la unidad        0
# Categoría económica                   0
# Ingresos de origen                    0
# Especies de ingresos                  0
# Detalle                               0
# Valor esperado actualizado        14625
# Valor lanzado                     40023
# Valor                              6336
# Porcentaje                        20880
# Fecha de lanzamiento                  0
# Año                                   0
# dtype: int64

# %%
# Reemplazar todos los ceros con NaN en el dataframe completo
df.replace(0, np.nan, inplace=True)

# %%
# Calcular el porcentaje de valores nulos en cada columna
porcentaje_nulos = df.isnull().sum() / len(df) * 100
print(porcentaje_nulos)
# Out:
# Código de órganos más alto         0.000000
# Nombre Superior                    0.000000
# Código corporal                    0.000000
# Órgano de nombre                   0.000000
# Código de la unidad de gestión     0.000000
# Nombre de gestión de la unidad     0.000000
# Categoría económica                0.000000
# Ingresos de origen                 0.000000
# Especies de ingresos               0.000000
# Detalle                            0.000000
# Valor esperado actualizado        36.127168
# Valor lanzado                     98.866163
# Valor                             15.651401
# Porcentaje                        51.578479
# Fecha de lanzamiento               0.000000
# Año                                0.000000
# dtype: float64

# %% [markdown]
# - los valores nulos de la columna "valor lanzado" representan el 98%, lo cual conviene eliminar dicha columna.
#
# - la columna porcentaje, que representa "Porcentaje de ejecución respecto al valor previsto." contiene casi la mitad de valores nulos y es una de las columnas más importantes para el análisis, pero pueden calcularse a partir del siguiente cálculo:
#
#         - Imputar 'Previsión' y 'Real' donde deseas calcular 'Porcentaje'.
#         - Calcula los valores de 'Porcentaje' para las filas donde es posible, basándote en las otras columnas.
#         - Imputar los valores nulos de la columna 'Porcentaje' con los valores calculados.

# %%
# Renombrar las columnas
df.rename(columns={
    'Valor esperado actualizado': 'Previsión',
    'Valor lanzado': 'Lanzado',
    'Valor': 'Real'
}, inplace=True)

# Seleccionar las columnas con los nuevos nombres
columnas_de_interes = ['Previsión', 'Lanzado', 'Real', 'Porcentaje']

# %% [markdown]
# # Visualización de la distribución de los nulos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Seleccionar las columnas con los nuevos nombres
columnas_de_interes = ['Previsión', 'Real', 'Porcentaje']

# Crear una máscara booleana para los valores nulos solo en las columnas seleccionadas
mask_nulls = df[columnas_de_interes].isnull()

# Añadir la columna 'Año' a la máscara de nulos para poder agrupar por año
mask_nulls['Año'] = df['Año']

# Contar los nulos por año para cada columna seleccionada
nulls_per_year = mask_nulls.groupby('Año').sum()

# Crear un gráfico de barras apiladas para visualizar los nulos por año
plt.figure(figsize=(12, 8))
nulls_per_year.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='coolwarm')
plt.title('Distribución de Valores Nulos por Año para Columnas Seleccionadas', fontsize=16)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Cantidad de Valores Nulos', fontsize=12)
plt.legend(title='Columnas', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Cálculo de Nulos repecto el total del DataFrame

# %%
# Número total de celdas
total_celdas = df.shape[0] * df.shape[1]

# Número total de valores nulos
total_nulos = df.isnull().sum().sum()

# Porcentaje de valores nulos
porcentaje_nulos = (total_nulos / total_celdas) * 100
print(f"El porcentaje de valores nulos en el DataFrame es: {porcentaje_nulos:.2f}%")
# Out:
# El porcentaje de valores nulos en el DataFrame es: 12.64%

# %% [markdown]
# Aunque moderado (no es más de un 20%), sugiere que el problema está localizado en unas pocas columnas clave. El enfoque debe estar en tratar las columnas más relevantes (como porcentaje, previsión y real).

# %% [markdown]
# - En el presente gráfico podemos observar como los nulos se distribuyen igual según los años.
#
# - Pasos siguientes:
#
#         - Eliminar filas con NA en Previsión ya que no representa información relevante con un 98% de nulos.
#         - Análisis previo de la distribución de los datos
#         - Imputar previsión y real: Con 36.12% y 15.65% de nulos, usando algún estadístico.
#         - Calcular en base a Real y Previsión el porcentaje y reemplazar los nulos con lo calculado.

# %% [markdown]
# ## 2. Imputación Nan

# %% [markdown]
# ### 2.1 Análisis previo de la distribución de los datos

# %%
# Aplicar logaritmo (sumar 1 para evitar log(0))
df['Log_Real'] = np.log1p(df['Real'])

# Histograma
df['Log_Real'].hist(bins=30)
plt.title('Distribución de la columna Real (escala logarítmica)')
plt.show()

# Boxplot
df.boxplot(column='Log_Real')
plt.show()
# Out:
# c:\Users\marta\anaconda3\envs\prueba2\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Detectar outliers (mayores al percentil 95)
outliers = df[df['Real'] > df['Real'].quantile(0.95)]
print(f"Cantidad de outliers: {len(outliers)}")
# Out:
# Cantidad de outliers: 1701

# %%
print(df['Real'].describe())
print(df['Previsión'].describe())
# Out:
# count    3.414600e+04
# mean     4.991075e+10
# std      8.335784e+11
# min     -2.763988e+10
# 25%      7.321040e+05
# 50%      1.093272e+07
# 75%      1.822960e+08
# max      4.137862e+13
# Name: Real, dtype: float64
# count    2.585700e+04
# mean     7.569269e+10
# std      1.283313e+12
# min      1.000000e+02
# 25%      3.244100e+06
# 50%      3.729160e+07
# 75%      6.011057e+08
# max      6.100657e+13
# Name: Previsión, dtype: float64

# %% [markdown]
# ### 2.3. Imputación de REAL y Previsión por la mediana. (Justificar)

# %%
# Imputar los datos faltantes en la columna 'REAL' por la mediana
mediana_real = df['Real'].median()
df['Real'] = df['Real'].fillna(mediana_real)

# Imputar los datos faltantes en la columna 'PREVISION' por la mediana
mediana_prevision = df['Previsión'].median()
df['Previsión'] = df['Previsión'].fillna(mediana_prevision)

# %%
nulos_interes = df[columnas_de_interes].isnull().sum() / len(df) * 100
print(nulos_interes)
# Out:
# Previsión      0.000000
# Real           0.000000
# Porcentaje    51.578479
# dtype: float64

# %%
# Calcular el porcentaje de valores nulos en esas columnas
porcentaje_nulos = df[columnas_de_interes].isnull().mean() * 100

# Mostrar los porcentajes
print(porcentaje_nulos)
# Out:
# Previsión      0.000000
# Real           0.000000
# Porcentaje    51.578479
# dtype: float64

# %% [markdown]
# ### 2.4 Cálculo de la columna porcentaje e imputación de nulos con lo calculado.

# %%
df = df.drop(columns=['Lanzado'])

# %%
# Calcular 'Porcentaje' para las filas donde 'Real' y 'Previsión' no son nulos
df['Porcentaje_calculado'] = (df['Real'] / df['Previsión']) * 100

# Imputar los nulos en 'Porcentaje' con los valores calculados
df['Porcentaje'] = df['Porcentaje'].fillna(df['Porcentaje_calculado'])

# Eliminar la columna auxiliar
df.drop('Porcentaje_calculado', axis=1, inplace=True)

# %%
print(df['Porcentaje'].isnull().sum())
print(df['Porcentaje'])
# Out:
# 0
# 0           0.347834
# 1        7150.838639
# 2          80.782570
# 3           0.497587
# 4          13.981883
#             ...
# 40477       0.002236
# 40478       0.000075
# 40479      16.516596
# 40480     133.000000
# 40481     220.000000
# Name: Porcentaje, Length: 40482, dtype: float64

# %% [markdown]
# # Análisis Descriptivo de las Variables

# %%
print(df['Real'].describe())
print(df['Previsión'].describe())
print(df['Porcentaje'].describe())
# Out:
# count    4.048200e+04
# mean     4.210073e+10
# std      7.657838e+11
# min     -2.763988e+10
# 25%      1.219126e+06
# 50%      1.093272e+07
# 75%      9.784969e+07
# max      4.137862e+13
# Name: Real, dtype: float64
# count    4.048200e+04
# mean     4.836054e+10
# std      1.026266e+12
# min      1.000000e+02
# 25%      1.405210e+07
# 50%      3.729160e+07
# 75%      1.109590e+08
# max      6.100657e+13
# Name: Previsión, dtype: float64
# count    4.048200e+04
# mean     7.226238e+03
# std      1.158751e+05
# min     -7.411826e+04
# 25%      4.362406e+00
# 50%      6.700000e+01
# 75%      1.610000e+02
# max      4.307200e+06
# Name: Porcentaje, dtype: float64

# %% [markdown]
# ## Variable `Real` (Monto realizado)
#
# - **Media (`mean`)**: \( 4.21 \times 10^{10} \), lo que indica que, en promedio, los valores de esta columna son bastante grandes.
# - **Desviación estándar (`std`)**: \( 7.65 \times 10^{11} \), una desviación enorme en comparación con la media, lo que sugiere una alta variabilidad en los datos.
# - **Mínimo (`min`)**: \( -2.76 \times 10^{10} \), lo cual es problemático, ya que los valores negativos pueden no tener sentido dependiendo del contexto (e.g., ingresos no pueden ser negativos).
# - **Percentiles**:
#   - **25%**: \( 1.22 \times 10^6 \), lo que indica que el 25% más bajo tiene valores pequeños en comparación con el rango total.
#   - **75%**: \( 9.78 \times 10^7 \), lo que significa que el 25% superior contiene valores mucho mayores, resaltando una distribución sesgada hacia valores altos.
# - **Máximo (`max`)**: \( 4.14 \times 10^{13} \), un valor extremo que podría ser un outlier significativo.
#
# **Conclusión**: La variable tiene valores extremadamente dispersos, con un rango que abarca desde números negativos hasta valores masivos. Los valores negativos deben ser investigados, y la transformación logarítmica es apropiada para manejar la alta dispersión y posibles outliers.
#
# ---
#
# ## Variable `Previsión` (monto ingreso previsto)
#
# - **Media (`mean`)**: \( 4.83 \times 10^{10} \), un promedio similar al de `Real`, lo que indica que ambas variables están relacionadas en magnitud.
# - **Desviación estándar (`std`)**: \( 1.03 \times 10^{12} \), incluso mayor que la de `Real`, lo que sugiere mayor variabilidad en esta columna.
# - **Mínimo (`min`)**: \( 100 \), no hay valores negativos, lo cual es un comportamiento esperado en montos previstos.
# - **Percentiles**:
#   - **25%**: \( 1.41 \times 10^7 \), los valores más pequeños son notablemente mayores que los de `Real`.
#   - **50%**: \( 3.73 \times 10^7 \), indica una mediana bastante por debajo de la media, lo que sugiere una distribución sesgada hacia valores altos.
#   - **75%**: \( 1.11 \times 10^8 \), similar a `Real`.
# - **Máximo (`max`)**: \( 6.10 \times 10^{13} \), un outlier incluso más grande que el de `Real`.
#
# **Conclusión**: Aunque no hay valores negativos, esta variable también tiene una dispersión extrema, con outliers significativos. La transformación logarítmica será útil para analizar la distribución con mayor claridad.
#
# ---
#
# ## Variable `Porcentaje` (Porcentaje de ejecución)
#
# - **Tamaño del conjunto de datos (`count`)**: Igual a las otras variables, con 40,482 registros.
# - **Media (`mean`)**: \( 7,226 \), lo cual es sorprendentemente alto para una columna que representa porcentajes (esperaríamos valores entre 0 y 100 en general).
# - **Desviación estándar (`std`)**: \( 1.16 \times 10^5 \), un valor desproporcionado, lo que confirma la presencia de valores extremos.
# - **Mínimo (`min`)**: \( -74,118 \), un valor negativo que, al igual que en `Real`, debe ser investigado, ya que porcentajes negativos suelen ser inconsistentes.
# - **Percentiles**:
#   - **25%**: \( 4.36 \), lo que indica que una cuarta parte de los datos tiene valores cercanos a 0.
#   - **50%**: \( 67 \), la mediana está en un rango esperado para porcentajes.
#   - **75%**: \( 161 \), lo que indica que un cuarto de los valores supera el 100%, un comportamiento que puede o no ser esperado según el contexto.
# - **Máximo (`max`)**: \( 4.31 \times 10^6 \), un valor fuera de escala para una columna de porcentajes.
#
# **Conclusión**: La columna `Porcentaje` contiene valores extremadamente atípicos (outliers), tanto negativos como extremadamente altos, que requieren ser tratados antes del análisis. Es necesario explorar las razones de estos valores y verificar si son errores.
#
# ---
#
# # Conclusiones Generales
#
# 1. **Dispersión alta y valores extremos**:
#    - Las tres variables tienen una desviación estándar muy alta, indicando alta variabilidad en los datos.
#    - Los valores extremos (máximos y mínimos) hacen difícil interpretar los datos directamente.
#
# 2. **Transformación necesaria**:
#    - La transformación logarítmica ayudará a comprimir la escala de los valores extremos y reducir la influencia de los outliers en el análisis.
#    - Es importante sumar 1 a los valores de `Real` y `Porcentaje` para manejar los valores negativos y nulos.
#
# 3. **Análisis adicional**:
#    - Investigar los valores negativos en `Real` y `Porcentaje`.
#    - Verificar la validez de los valores máximos (¿son errores o casos válidos?).
#    - Comparar los valores transformados para identificar patrones más claros.
#
# En resumen, las estadísticas iniciales sugieren que las tres variables requieren limpieza y transformación antes de proceder a un análisis más detallado.
#
# Dado nuestro objetivo, es crucial que se mantengan tanto los valores negativos como los positivos en el análisis, ya que estos pueden ser indicadores importantes de problemas como fraudes, errores o deficiencias en la ejecución presupuestaria. La transformación logarítmica es útil para manejar la escala de valores extremos, pero también tiene limitaciones, especialmente en este caso donde los valores negativos son significativos.

# %% [markdown]
# ### Invstigár mínimos y anómalos

# %%
negativos_real = df[df['Real'] < 0]
negativos_real
# Out:
#        Código de órganos más alto  \
# 53                          22000
# 78                          22000
# 81                          22000
# 135                         22000
# 543                         52000
# ...                           ...
# 39746                       41000
# 39784                       35000
# 39892                       32000
# 40008                       53000
# 40200                       53000
#
#                                      Nombre Superior  Código corporal  \
# 53     Ministério da Agricultura, Pecuária e Abastec            22211
# 78     Ministério da Agricultura, Pecuária e Abastec            22211
# 81     Ministério da Agricultura, Pecuária e Abastec            22000
# 135    Ministério da Agricultura, Pecuária e Abastec            22202
# 543                             Ministério da Defesa            52121
# ...                                              ...              ...
# 39746                    Ministério das Comunicações            41231
# 39784             Ministério das Relações Exteriores            35000
# 39892                  Ministério de Minas e Energia            29208
# 40008         Ministério do Desenvolvimento Regional            22203
# 40200         Ministério do Desenvolvimento Regional            22204
#
#                                         Órgano de nombre  \
# 53                   Companhia Nacional de Abastecimento
# 78                   Companhia Nacional de Abastecimento
# 81     Ministério da Agricultura, Pecuária e Abasteci...
# 135          Empresa Brasileira de Pesquisa Agropecuária
# 543                                  Comando do Exército
# ...                                                  ...
# 39746              Agêncial Nacional de Telecomunicações
# 39784  Ministério das Relações Exteriores - Unidades ...
# 39892         Companhia de Pesquisa de Recursos Minerais
# 40008  Companhia de Desenvolvimento dos Vales do São ...
# 40200     Departamento Nacional de Obras Contra as Secas
#
#        Código de la unidad de gestión  \
# 53                             135100
# 78                             135100
# 81                             130101
# 135                            135037
# 543                            160075
# ...                               ...
# 39746                          413001
# 39784                          240999
# 39892                          495001
# 40008                          195006
# 40200                          113802
#
#                       Nombre de gestión de la unidad  \
# 53               COMPANHIA NACIONAL DE ABASTECIMENTO
# 78               COMPANHIA NACIONAL DE ABASTECIMENTO
# 81         COORD.-GERAL DE ORCAMENTO E FINANCAS-MAPA
# 135                                 EMBRAPA-SETORIAL
# 543                     D CONT - SETORIAL FINANCEIRA
# ...                                              ...
# 39746      AGENCIA NACIONAL DE TELECOMUNICACOES-SEDE
# 39784                        MRE - DIFERENCA CAMBIAL
# 39892     COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 40008  CIA DE DES.DOS VALES DO S.FRANC.E DO PARNAIBA
# 40200  DEPARTAMENTO NAC. DE OBRAS CONTRA AS SECAS/UO
#
#                             Categoría económica  \
# 53                          Receitas de Capital
# 78                          Receitas de Capital
# 81                          Receitas de Capital
# 135                          Receitas Correntes
# 543                          Receitas Correntes
# ...                                         ...
# 39746  Receitas Correntes - intra-orçamentárias
# 39784                        Receitas Correntes
# 39892                        Receitas Correntes
# 40008                        Receitas Correntes
# 40200                        Receitas Correntes
#
#                        Ingresos de origen  \
# 53                      Alienação de Bens
# 78                      Alienação de Bens
# 81                      Alienação de Bens
# 135                   Receita de Serviços
# 543                   Receita Patrimonial
# ...                                   ...
# 39746                       Contribuições
# 39784  Receitas Correntes - a classificar
# 39892                 Receita Patrimonial
# 40008           Outras Receitas Correntes
# 40200                 Receita Patrimonial
#
#                                 Especies de ingresos  \
# 53                          Alienação de bens móveis
# 78                          Alienação de bens móveis
# 81                          Alienação de bens móveis
# 135                              Receita de Serviços
# 543                     Demais receitas patrimoniais
# ...                                              ...
# 39746                       Contribuições econômicas
# 39784             Receitas Correntes - a classificar
# 39892                   Demais receitas patrimoniais
# 40008    Indenizações, restituições e ressarcimentos
# 40200  Exploração do patrimônio imobiliário do Estad
#
#                                              Detalle   Previsión        Real  \
# 53                  ALIENACAO DE TITULOS MOBILIARIOS  37291600.0     -3520.0
# 78                   ALIENACAO DE OUTROS BENS MOVEIS    103100.0   -122480.0
# 81                   ALIENACAO DE OUTROS BENS MOVEIS  35995600.0  -3500750.0
# 135                       OUTROS SERVICOS COMERCIAIS  37291600.0     -3790.0
# 543                     Demais receitas patrimoniais  37291600.0     -9100.0
# ...                                              ...         ...         ...
# 39746  CONTRIBUICAO PARA FOMENTO DA RADIODIFUSAO PUB  37291600.0    -52839.0
# 39784             Receitas Correntes - a classificar  37291600.0 -13151298.0
# 39892                   Demais receitas patrimoniais  37291600.0  -1185690.0
# 40008                            OUTRAS RESTITUICOES  37291600.0   -291445.0
# 40200                OUTRAS RECEITAS DE BENS IMOVEIS  37291600.0  -4669364.0
#
#        Porcentaje Fecha de lanzamiento   Año  Log_Real
# 53      -0.009439           2013-12-31  2013       NaN
# 78    -119.000000           2013-12-31  2013       NaN
# 81     -10.000000           2013-12-31  2013       NaN
# 135     -0.010163           2013-12-31  2013       NaN
# 543     -0.024402           2013-12-31  2013       NaN
# ...           ...                  ...   ...       ...
# 39746   -0.141691           2013-12-31  2021       NaN
# 39784  -35.266114           2013-12-31  2021       NaN
# 39892   -3.179510           2013-12-31  2021       NaN
# 40008   -0.781530           2013-12-31  2021       NaN
# 40200  -12.521222           2013-12-31  2021       NaN
#
# [342 rows x 16 columns]

# %%
df = df.drop ('Log_Real', axis = 1)

# %%
df.shape
# Out:
# (40482, 15)

# %% [markdown]
# ## Transformación logarítmica simétrica que mantenga valores negativos
# la transformación log-simétrica:
#
# - Incluye valores negativos en el análisis.
# - Hace más fácil visualizar y comparar las distribuciones de las variables.
# - Mantiene la relación de magnitudes entre valores.

# %%
def log_simetrico(x):
    if x >= 0:
        return np.log1p(x)  # Logaritmo natural clásico para valores positivos
    else:
        return -np.log1p(-x)  # Logaritmo simétrico para valores negativos

# Aplicar la transformación a las columnas relevantes
df['Log_Real'] = df['Real'].apply(log_simetrico)
df['Log_Previsto'] = df['Previsión'].apply(log_simetrico)
df['Log_Porcentaje'] = df['Porcentaje'].apply(log_simetrico)

# %%
df[['Log_Real', 'Log_Previsto', 'Log_Porcentaje']].hist(bins=30, figsize=(10, 6))
plt.suptitle('Distribuciones transformadas (log-simétrico)')
plt.show()

# %%
# Calcular el percentil 75% para cada variable transformada
p75_real = np.percentile(df['Log_Real'], 75)
p75_previsto = np.percentile(df['Log_Previsto'], 75)
p75_porcentaje = np.percentile(df['Log_Porcentaje'], 75)

# Filtrar los datos
df_filtered = df[
    (df['Log_Real'] <= p75_real) &
    (df['Log_Previsto'] <= p75_previsto) &
    (df['Log_Porcentaje'] <= p75_porcentaje)
]

# Visualizar las distribuciones filtradas
df_filtered[['Log_Real', 'Log_Previsto', 'Log_Porcentaje']].hist(bins=30, figsize=(10, 6))
plt.suptitle('Distribuciones filtradas (por debajo del percentil 75%)')
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Antes del filtrado
df[['Log_Real', 'Log_Previsto', 'Log_Porcentaje']].hist(bins=30, ax=axes[0], color='blue')
axes[0][0].set_title('Log_Real (Original)')
axes[0][1].set_title('Log_Previsto (Original)')
axes[0][2].set_title('Log_Porcentaje (Original)')

# Después del filtrado
df_filtered[['Log_Real', 'Log_Previsto', 'Log_Porcentaje']].hist(bins=30, ax=axes[1], color='green')
axes[1][0].set_title('Log_Real (Filtrado)')
axes[1][1].set_title('Log_Previsto (Filtrado)')
axes[1][2].set_title('Log_Porcentaje (Filtrado)')

plt.suptitle('Comparación de Distribuciones: Antes y Después del Filtrado')
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Conclusiones:
# - Sobre la distribución de las variables:
#         - Log_Real y Log_Previsto muestran distribuciones asimétricas con colas largas hacia valores altos, lo que indica la presencia de valores extremos importantes.
#         - Log_Porcentaje tiene una distribución multimodal con valores negativos significativos, que son cruciales para detectar anomalías.
# - Sobre el filtrado:
#
#         -El filtrado simplifica las distribuciones, pero también elimina información potencialmente valiosa, especialmente para -Log_Porcentaje, donde los valores extremos negativos son importantes para el análisis de fraudes.
#         -El filtrado podría ser útil para explorar la parte central de las distribuciones, pero no es relevante si el objetivo es analizar desviaciones significativas.

# %% [markdown]
# ## Análisis de desviaciones
#
# - El siguiente paso es calcular y analizar directamente las desviaciones entre lo previsto y lo ejecutado. Vamos a calcular dos métricas clave:
#
# 1. Diferencia Absoluta = Real - Previsión
#
# 2. Diferencia relativa (o porcentaje de desviación): Real - Previsión / Previsión * 100

# %%
# Calcular las desviaciones
df['Diferencia_Absoluta'] = df['Real'] - df['Previsión']
df['Porcentaje_Desviación'] = ((df['Real'] - df['Previsión']) / df['Previsión']) * 100

# %%
# Aplicar transformación logarítmica a las métricas (agregar un pequeño valor para evitar log(0))
df['Log_Diferencia_Absoluta'] = np.log1p(df['Diferencia_Absoluta'].abs())  # abs para manejar negativos
df['Log_Porcentaje_Desviación'] = np.log1p(df['Porcentaje_Desviación'].abs())

# Filtrar el rango de percentiles para valores representativos
p5_abs = np.percentile(df['Diferencia_Absoluta'], 5)
p95_abs = np.percentile(df['Diferencia_Absoluta'], 95)
p5_dev = np.percentile(df['Porcentaje_Desviación'], 5)
p95_dev = np.percentile(df['Porcentaje_Desviación'], 95)

df_filtrado = df[
    (df['Diferencia_Absoluta'] >= p5_abs) & (df['Diferencia_Absoluta'] <= p95_abs) &
    (df['Porcentaje_Desviación'] >= p5_dev) & (df['Porcentaje_Desviación'] <= p95_dev)
]

# Visualizar las distribuciones transformadas y filtradas
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Diferencia Absoluta - Transformada
df['Log_Diferencia_Absoluta'].hist(bins=30, ax=axes[0, 0], color='orange')
axes[0, 0].set_title('Log de Diferencia Absoluta (Transformada)')
axes[0, 0].set_xlabel('Log(Diferencia Absoluta)')
axes[0, 0].set_ylabel('Frecuencia')

# Porcentaje de Desviación - Transformado
df['Log_Porcentaje_Desviación'].hist(bins=30, ax=axes[0, 1], color='purple')
axes[0, 1].set_title('Log del Porcentaje de Desviación (Transformado)')
axes[0, 1].set_xlabel('Log(Porcentaje de Desviación)')
axes[0, 1].set_ylabel('Frecuencia')

# Diferencia Absoluta - Filtrada
df_filtrado['Diferencia_Absoluta'].hist(bins=30, ax=axes[1, 0], color='orange')
axes[1, 0].set_title('Diferencia Absoluta (Filtrada)')
axes[1, 0].set_xlabel('Diferencia Absoluta')
axes[1, 0].set_ylabel('Frecuencia')

# Porcentaje de Desviación - Filtrado
df_filtrado['Porcentaje_Desviación'].hist(bins=30, ax=axes[1, 1], color='purple')
axes[1, 1].set_title('Porcentaje de Desviación (Filtrado)')
axes[1, 1].set_xlabel('Porcentaje de Desviación')
axes[1, 1].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %%
df.head(3)
# Out:
#    Código de órganos más alto           Nombre Superior  Código corporal  \
# 0                       63000  Advocacia-Geral da União            63000
# 1                       63000  Advocacia-Geral da União            63000
# 2                       63000  Advocacia-Geral da União            63000
#
#                                     Órgano de nombre  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
# 2  Advocacia-Geral da União - Unidades com víncul...
#
#    Código de la unidad de gestión  \
# 0                          110060
# 1                          110060
# 2                          110060
#
#                   Nombre de gestión de la unidad Categoría económica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 2  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#           Ingresos de origen                           Especies de ingresos  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
# 2  Outras Receitas Correntes  Multas administrativas, contratuais e judicia
#
#                                          Detalle   Previsión          Real  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC  37291600.0  1.297130e+05
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES  37291600.0  2.666662e+09
# 2                  OUTRAS MULTAS E JUROS DE MORA  37291600.0  3.012511e+07
#
#     Porcentaje Fecha de lanzamiento   Año   Log_Real  Log_Previsto  \
# 0     0.347834           2013-12-31  2013  11.773087     17.434279
# 1  7150.838639           2013-12-31  2013  21.704093     17.434279
# 2    80.782570           2013-12-31  2013  17.220870     17.434279
#
#    Log_Porcentaje  Diferencia_Absoluta  Porcentaje_Desviación  \
# 0        0.298499        -3.716189e+07             -99.652166
# 1        8.875125         2.629371e+09            7050.838639
# 2        4.404064        -7.166487e+06             -19.217430
#
#    Log_Diferencia_Absoluta  Log_Porcentaje_Desviación
# 0                17.430794                   4.611671
# 1                21.690010                   8.861044
# 2                15.784926                   3.006545

# %% [markdown]
# Análisis Posterior
#
# - Identificar si hay concentraciones o patrones en las desviaciones.
# - Focalizar en valores extremos (positivos y negativos) para investigar posibles fraudes o errores.
# - Desglosar las desviaciones por categorías económicas o tipos de ingresos para determinar dónde son más pronunciadas.

# %% [markdown]
# Pasos siguientes tras la corrección:
#
# - Interpretar las distribuciones transformadas:
#
# - Ver si los valores extremos tienen un comportamiento distinto.
# - Identificar si existen agrupaciones o patrones significativos.
# - Desglosar por categorías económicas o tipos de ingresos:
#
# Comparar las desviaciones (Diferencia Absoluta y Porcentaje de Desviación) por subgrupos para determinar dónde son más pronunciadas.

# %%
# Transformación logarítmica con signo
def log_transform_signed(x):
    return np.sign(x) * np.log1p(np.abs(x))

# Aplicar a las columnas
df['Log_Diferencia_Absoluta'] = df['Diferencia_Absoluta'].apply(log_transform_signed)
df['Log_Porcentaje_Desviación'] = df['Porcentaje_Desviación'].apply(log_transform_signed)

# Visualización de las distribuciones transformadas
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Log(Diferencia Absoluta) con signo
df['Log_Diferencia_Absoluta'].hist(bins=30, ax=axes[0], color='orange')
axes[0].set_title('Log de Diferencia Absoluta (Con signo)')
axes[0].set_xlabel('Log(Diferencia Absoluta)')
axes[0].set_ylabel('Frecuencia')

# Log(Porcentaje de Desviación) con signo
df['Log_Porcentaje_Desviación'].hist(bins=30, ax=axes[1], color='purple')
axes[1].set_title('Log del Porcentaje de Desviación (Con signo)')
axes[1].set_xlabel('Log(Porcentaje de Desviación)')
axes[1].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Código de órganos más alto', 'Nombre Superior', 'Código corporal',
#        'Órgano de nombre', 'Código de la unidad de gestión',
#        'Nombre de gestión de la unidad', 'Categoría económica',
#        'Ingresos de origen', 'Especies de ingresos', 'Detalle', 'Previsión',
#        'Real', 'Porcentaje', 'Fecha de lanzamiento', 'Año', 'Log_Real',
#        'Log_Previsto', 'Log_Porcentaje', 'Diferencia_Absoluta',
#        'Porcentaje_Desviación', 'Log_Diferencia_Absoluta',
#        'Log_Porcentaje_Desviación'],
#       dtype='object')
